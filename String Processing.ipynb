# %%
import pandas as pd

# %%
data = pd.read_excel("data.xlsx")

# %%
titles = data['Title'].values
print(titles[0])
# Out:
# Saba Getenet - Beza (በዛ) [NEW! Ethiopian Music Video 2017]

# %%
for title in titles[:150]:
    title_list = title.split(" - ")
    print(title_list[0])
# Out:
# Saba Getenet
# Abel Samuel
# Biniam Belay aka Bini Boy [NEW! Ethiopian Music Video 2017] OFFICIAL VIDEO
# BG Man
# Ethiopia
# Embeza Sebhatleab
# Ethiopia: Fedlu Hiyar
# NEFSIH TEDDY X
# Getahun Ketema
# Mele Zan Jar
# Neba Yo
# Remedan Chimesa
# Afrobika Totoba
# Abera Werku
# Exien Girma
# Teddy X
# Teddy X
# Debebe Adame
# Debebe Ademe
# Neba Yo
# Adam Mohammed
# Tofiq Abdella
# Assefa Yadesa
# Dereje Delelegn Bemin Kal Lasredash (በምን ቃል ላስረዳሽ) New Ethiopian Music Video 2016
# Desalegn Berhanu
# Smizz Mayle
# Yiftusera Zerihun
# Mekonnen Asefa
# Khalid
# Abraham Nigussie
# Kebe Bekele
# Lencho Gudina
# Semahegn Asfaw
# Semahegn Asfaw
# Mele Zan Jar
# Mele Zan Jar
# Luwam Teame
# Halima Abdurahman ft. Jah Lud
# C. A. N Squad
# Muchot Hagos
# Muchot Hagos
# Temesgen & kasahun GIBE 3 2015 Ethiopian Music
# Habaaboo Bashaaduu
# Ibrahim Roba
# Tinsu Ragga
# Smizz Mayle
# Habl Tiruneh
# Haftom Gidey
# Neba Yo /Fano Boyz/
# Habl Tiruneh
# Yared Atlaw
# ...
